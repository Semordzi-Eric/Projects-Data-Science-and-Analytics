# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/DELL/Downloads/Literacy Rate inflation GDP in Bangladesh Dataset - RAW.csv')
df.head()
# Out:
#      Year  Literacy Rate(%) Population  Population growth rate (%)  \
# 0  1980.0              26.0  83,929,765                      2.47%
# 1  1981.0              27.0  86,154,836                      2.65%
# 2  1982.0              27.8  88,555,336                      2.79%
# 3  1983.0              28.2  91,045,478                      2.81%
# 4  1984.0              28.8  93,534,239                      2.73%
#
#   Migrant Population (Estimated)  Net Migration Rate Growth Rate  \
# 0                        720,000              -2.569      -8.38%
# 1                        730,000              -2.333      -9.19%
# 2                        740,000              -2.098     -10.07%
# 3                        750,000              -1.863     -11.20%
# 4                        760,000              -1.581     -15.14%
#
#   Inflation Rate (%) Annual Change (%)  GNI (Billion USD)  ... Military Size   \
# 0               0.82             -0.82              18.48  ...            NaN
# ...

# %%
df.shape
# Out:
# (101, 118)

# %%
df.dropna()
# Out:
# Empty DataFrame
# ...

# %%
df.describe().T
# Out:
#                                          count           mean           std  \
# Year                                      44.0    2001.500000     12.845233
# Literacy Rate(%)                          44.0      48.115455     16.600579
# Net Migration Rate                        43.0      -2.162070      1.028741
# GNI (Billion USD)                         44.0     120.265000    133.834785
# Number of Private Vehichles                0.0            NaN           NaN
# Death Rate                                44.0       8.180159      2.988621
# Life Expectancy (years)                   44.0      64.452955      6.756697
# Urban Population % of Total               44.0      26.127045      7.512243
# Crime Rate (Per 100K Population)          19.0       2.647895      0.211702
#  Murder/Homicide Rate                     19.0       2.647895      0.211702
# Tree Cover Loss(hector)                   23.0   10687.708263   7863.499627
# ...

# %%
df_numeric = df.select_dtypes(include='number')
df_numeric = df_numeric.drop(columns=['Number of Private Vehichles'])
df_numeric.describe().T
# Out:
#                                          count           mean           std  \
# Year                                      44.0    2001.500000     12.845233
# Literacy Rate(%)                          44.0      48.115455     16.600579
# Net Migration Rate                        43.0      -2.162070      1.028741
# GNI (Billion USD)                         44.0     120.265000    133.834785
# Death Rate                                44.0       8.180159      2.988621
# Life Expectancy (years)                   44.0      64.452955      6.756697
# Urban Population % of Total               44.0      26.127045      7.512243
# Crime Rate (Per 100K Population)          19.0       2.647895      0.211702
#  Murder/Homicide Rate                     19.0       2.647895      0.211702
# Tree Cover Loss(hector)                   23.0   10687.708263   7863.499627
# Tree cover loss due to fires              23.0      53.000000     32.904821
# ...

# %%
df_numeric = df_numeric.fillna(0, inplace=True)

# %%
df_numeric.describe().T
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df_numeric.describe().T
#
# AttributeError: 'NoneType' object has no attribute 'describe'

# %%
df_numeric.isnull().sum()
# Out:
# Year                                       0
# Literacy Rate(%)                           0
# Net Migration Rate                         0
# GNI (Billion USD)                          0
# Death Rate                                 0
# Life Expectancy (years)                    0
# Urban Population % of Total                0
# Crime Rate (Per 100K Population)           0
#  Murder/Homicide Rate                      0
# Tree Cover Loss(hector)                    0
# Tree cover loss due to fires               0
# Percentage of cover tree                   0
# Primary forest loss(hector)                0
# gross_emissions_co2e_all_gases(Megaton)    0
# Primary forest extent remaining(%)         0
# annual forestry                            0
# annual shifting agriculture                0
# Annual tree cover loss                     0
# deforestation for urbanizations            0
# commodity driven deforestation             0
# Carbon emissionMetric Tons Per Capita      0
# ...

# %%
df_numeric.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 df_numeric.info()
#
# AttributeError: 'NoneType' object has no attribute 'info'

# %%
corr = df_numeric.corr()
plt.figure(figsize=(12,5))
sns.heatmap(corr, annot=True, fmt = '.2f', cmap = 'coolwarm')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 corr = df_numeric.corr()
#       2 plt.figure(figsize=(18,5))
#       3 sns.heatmap(corr, annot=True, fmt = '.2f', cmap = 'coolwarm')
#
# AttributeError: 'NoneType' object has no attribute 'corr'
